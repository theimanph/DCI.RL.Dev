# %%
# %pip install pyodbc
# %pip install duckdb
# %pip install splink
# %pip install usaddress
# %pip install nbformat
# Out:
# Requirement already satisfied: pyodbc in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (5.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: duckdb in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (0.9.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: splink in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (3.9.12)
# Requirement already satisfied: Jinja2>=3.0.3 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (3.1.3)
# Requirement already satisfied: altair<6.0.0,>=5.0.1 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (5.2.0)
# Requirement already satisfied: duckdb>=0.8.0 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (0.9.2)
# Requirement already satisfied: jsonschema<5.0,>=3.2 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (4.21.1)
# Requirement already satisfied: pandas>1.3.0 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (2.2.0)
# Requirement already satisfied: phonetics<2.0.0,>=1.0.5 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (1.0.5)
# Requirement already satisfied: sqlglot<19.0.0,>=13.0.0 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (18.17.0)
# Requirement already satisfied: numpy in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from altair<6.0.0,>=5.0.1->splink) (1.26.3)
# Requirement already satisfied: packaging in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from altair<6.0.0,>=5.0.1->splink) (23.2)
# Requirement already satisfied: toolz in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from altair<6.0.0,>=5.0.1->splink) (0.12.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from Jinja2>=3.0.3->splink) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema<5.0,>=3.2->splink) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema<5.0,>=3.2->splink) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema<5.0,>=3.2->splink) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema<5.0,>=3.2->splink) (0.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from pandas>1.3.0->splink) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from pandas>1.3.0->splink) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from pandas>1.3.0->splink) (2023.4)
# Requirement already satisfied: six>=1.5 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>1.3.0->splink) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: usaddress in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (0.5.10)
# Requirement already satisfied: future>=0.14 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from usaddress) (0.18.3)
# Requirement already satisfied: probableparsing in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from usaddress) (0.0.1)
# Requirement already satisfied: python-crfsuite>=0.7 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from usaddress) (0.9.10)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nbformat in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (5.9.2)
# Requirement already satisfied: fastjsonschema in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from nbformat) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from nbformat) (4.21.1)
# Requirement already satisfied: jupyter-core in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from nbformat) (5.7.1)
# Requirement already satisfied: traitlets>=5.1 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from nbformat) (5.14.1)
# Requirement already satisfied: attrs>=22.2.0 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.17.1)
# Requirement already satisfied: platformdirs>=2.5 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jupyter-core->nbformat) (4.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc
import os
import pandas as pd
import re
import usaddress
import time
import phonetics
# Out:
# /tmp/ipykernel_13298/2033548867.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
os.environ['DW_SERVER'] = "pdsqlirisdw01.hosted.lac.com"
os.environ['DW_DB'] = "PRD_APHIM_UODS_DW"
os.environ['DW_USER'] = "zz_dssteam"
os.environ['DW_PASS'] = "$3rv1se0neF1ve"

# %%
# Set up the connection
sqdw_con = pyodbc.connect(
    driver='sqlserver', 
    server=os.getenv('DW_SERVER'),
    database=os.getenv('DW_DB'),
    uid=os.getenv('DW_USER'),
    pwd=os.getenv('DW_PASS'),
    TrustServerCertificate='YES',
    timeout=10
)

#Execute a query 10k
query = "SELECT top 10000 * FROM Fact.VW_Person WITH (NOLOCK) where PER_StreetAddress is not NULL"
dw_person_10k = pd.read_sql(query, sqdw_con)
dw_person_10k["id"] = dw_person_10k.index + 1

#Execute a query 100k
query = "SELECT top 100000 * FROM Fact.VW_Person WITH (NOLOCK) where PER_StreetAddress is not NULL"
dw_person_100k = pd.read_sql(query, sqdw_con)
dw_person_100k["id"] = dw_person_100k.index + 1


#Execute a query 1m
query = "SELECT top 1000000 * FROM Fact.VW_Person WITH (NOLOCK) where PER_StreetAddress is not NULL"
dw_person_1m = pd.read_sql(query, sqdw_con)
dw_person_1m["id"] = dw_person_1m.index + 1

#Execute a query 10m
query = "SELECT top 10000000 * FROM Fact.VW_Person WITH (NOLOCK) where PER_StreetAddress is not NULL"
dw_person_10m = pd.read_sql(query, sqdw_con)
dw_person_10m["id"] = dw_person_10m.index + 1
# Out:
# /tmp/ipykernel_13298/3441521814.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dw_person_10k = pd.read_sql(query, sqdw_con)
# /tmp/ipykernel_13298/3441521814.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dw_person_100k = pd.read_sql(query, sqdw_con)
# /tmp/ipykernel_13298/3441521814.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dw_person_1m = pd.read_sql(query, sqdw_con)
# /tmp/ipykernel_13298/3441521814.py:30: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dw_person_10m = pd.read_sql(query, sqdw_con)

# %%
#clean the data

# %%
input_df=dw_person_10k

# %%
# %pip install pyodbc
# %pip install duckdb
# %pip install splink

#----
import pyodbc
import os
import pandas as pd
import re
import time
#----

start_time = time.time()
print(f"Execution time: {time.time() - start_time}")


input_df=input_df
#----
def clean_addr(df, address_var, apt_var, city_var, state_var, zip_var):
    # Replace backslashes with forward slashes in address
    df[address_var] = df[address_var].str.replace(r"\\", "/", regex=True)

    # Extract fractions like '1/2' or '3/4' from the address
    df['addr_frac'] = df[address_var].str.extract(r"(1/2|3/4)", expand=False)
    df[address_var] = df[address_var].str.replace(r"1/2|3/4", "", regex=True).str.strip()

    # Remove unnecessary punctuation and convert to uppercase
    df[address_var] = df[address_var].str.replace(r"[^a-zA-Z0-9\s,]", " ", regex=True).str.upper().str.strip()
    df[apt_var] = df[apt_var].str.replace(r"[^a-zA-Z0-9\s#\-/]", " ", regex=True).str.upper().str.strip()

    # Remove entirely blank entries
    for var in [address_var, apt_var, city_var, state_var, zip_var]:
        df[var] = df[var].replace(r"^\s*$", "", regex=True)

    # Simple regex to extract street (assuming 'number streetname' format)
    street_regex = r"^\d+\s[\w\s]+"
    df['addr'] = df[address_var].apply(lambda x: re.match(street_regex, x).group() if re.match(street_regex, x) else '')

    # Assuming city, state, and zip are already separated correctly
    df['city'] = df[city_var]
    df['state'] = df[state_var]
    df['zip'] = df[zip_var]

    return df

#----
# Now apply the clean_addr function to the input DataFrame
cleaned_df1=clean_addr(df=input_df,
                        address_var="PER_StreetAddress",
                        apt_var="PER_Apartment", 
                        city_var="PER_City", 
                        state_var="PER_State",
                        zip_var="PER_Zip")

#----
# Define the keyword lists
invalid_addr1 = "|".join(["UNKNO", "HOMELES", "NEED ADDR", "NEED INFO", "HOMESLESS", "TRANSIENT", "SUPPRESS", "ENCAMPM", 
                          "UNDOMIC", "UNDERPASS", "HOMELESS", "NOADDRESS", "NO ADDRESS", "NONE PROVIDED", "REFUSED", 
                          "123 DEFAULT ST", "PT STATES NONE", "999 TRANSIENT WAY", "UNSHELTERED", "UNHOUSED", "UNKKNOWN", 
                          "UNKNWOWN", "UNKONW", "UNKOWN", "UNSTABLE HOUSING", "XNEEDX", "XNEEDSX", "HOMELEXX", "X NEED X", 
                          "TRANSET", "MISSING", "MAILING ADDRESS", "MAILING ONLY", "NOT AVAILABLE", "NOT PROVIDED", 
                          "THIS IS NOT A HOME ADDRESS", "MAIL RTND BAD ADDRESS", "MAILING ADDRESS ONLY", "NEED NEW ADDRESS", 
                          "FILLING OUT FORMS", "ADDRS VERF", "NO ACTUAL ADDRESS", "NEEDS ADDRESS", "DOES NOT HAVE AN ADDRESS", 
                          "REQUEST CALL", "UNABLE TO PROVIDE", "RETURN MAIL", "BAD ADDRESS", "UNABLE TO LOCATE", 
                          "NOT GIVEN", "NONE GIVEN", "NO KNOWN ADDRESS"])
peh_keywords = invalid_addr1 + "|450 BAUCHET"
peh_keywords1 = ['NOT PROVIDED', 'UNSPECIFIED', '*NONE', 'REFUSED', '`', 'NULL', 'NONE', 'NA', 'N/A',  
                 'ODR', 'SHELTER', 'IN TRANSIT', 'UNK']
peh_keywords2 = peh_keywords1 + ['CA', 'NOT CALIFORNIA', 'LAC']

# Continue defining the keyword lists
invalid_addr15 = "|UPDATE DEMO MAIL RTN|123 TEST|TEST PATIENT|TEST STREET|UPDATE DEMO|ROUTINE POSTPARTUM|" + \
                "123 MISSING|^HOMELES.*|^UNHOUSED.*|^UNSHELTER.*|^TRANSIENT.*|^UNK.*|^PRIV.*|^UNSPEC.*|^PT STATES.*|"
invalid_addr3 = peh_keywords1 + ['YES', '1234 ST', 'TBA', 'TBD', 'TEST 1', 'TEST', 'UNITED STATES', 'US', 'USA',
                                 'MAIL ONLY', 'MAIL RETURNED', 'MAILING', 'ANTHEM BLUE CROSS', 'SANTA MONICA BEACH',
                                 'SPRING', 'TEXT', 'NAME', '1 HOME', 'HOTEL', '1 FAKE', 'SPANISH', 
                                 'SPECIMEN NOT COLLECTED',  'UPDATE', '1 NEED', 'MAIN HOUSE', 'MANAGER', 
                                 'MANAGER OFFICE', 'MANAGER UNIT', 'XX', 'XX OTHER', 'PATIENT REFUSED', 
                                 'NOT PROVIDED', "^REFUS.*", "^NO ADDRESS.*", 'NOT AVAILABLE']
invalid_addr4 = invalid_addr3 + ['CALIFORNIA', 'CA']
invalid_addr5 = invalid_addr4 + ['LOS ANGELES', 'LA', '# LA', '#LA', 'N A', 'NA', '999 TRANSIENT WAY', 
                                 '999 TRANSIENT', '99 JAIL CASE', '123 UNK', '9999 TRANSIENT', '9999 TRANSIENT WAY', 
                                 '9999 TRANSIENT', 'SOUTHBAY ER', 'XXX HOMELESS XXX', 'POST OFFICE BOX', 
                                 'PTIENT STATES', 'SUNSET ED', 'VALLEY PALMS CARE CENTER', 'W LOS ANGELES ED', 
                                 'WLA ED', 'UNK']

# Invalid apartment numbers
invalid_apt1 = invalid_addr1 + "|UNITED CARE FACILITES|HEALTH CARE|WE DO HAVE A NEW REGISTRATION|" + \
               "UNITED CEREBRAL PALSEY|UNITED STATES"
invalid_apt2 = invalid_addr4 + ['YES', '-', '1 LAB', 'APT SUITE FLOOR ETC.', 'NO APT']
invalid_apt3 = invalid_addr5 + ["UNITED CARE FACILITES", "HEALTH CARE", "WE DO HAVE A NEW REGISTRATION", 
                                "UNITED CEREBRAL PALSEY", "UNITED STATES", "BELLFLOWER CHRISTIAN", 
                                "GRAND PARK CONVALESCENT", 'BRUIN PLAZA', 'YES', '-', '1 LAB', 
                                'APT SUITE FLOOR ETC', 'NO APT']

# Key phrases for invalid apartment units
invalid_apt_frag = ["CONV", "HEALTH", "MEDICAL", "NURSING", "ACUTE", "CARE", "SOBER", "REHAB", "ASSISTED",
                    "LIVING", "MANOR", "VILLA", "RETIREMENT", "BEH", "SENIOR", "SNF", "RESID", "SANIT", "CHURCH",
                    "ACUTE", "HEALTHCARE", "WELLNESS", "CONGREGATE", "CONVALESCENT", "GLENDORA GRAND", "REHABILITATION",
                    # Other terms
                    "HOME", "HOUSE", 'HEIGHT', 'COUNTRY', 'GARDEN', 'COTTAGE',  'ADDR', 'C/O', 
                    'POBOX', 'PLAZA', 'UNABLE', 'TRANSIENT', 'JAIL', 'PRISON', 'THE', 'SAME', 'VISTA', 'MAIL', 'PARK', 
                    'OFFICE', 'LAPD', 'LETTER', 'HOTEL', 'INN', 'MOTEL', 'COUNTY', 'UPPER', 'LOWER', 'REAR', 'DOWN', 
                    'UP', 'TEST', 'UNI', 'STADIUM']

# Invalid cities
invalid_city = ['NULL', 'NONE', 'NA', 'N/A', 'YES', 'REFUSED', '`', 'NOT PROVIDED', 'UNK', '', 'UNKKNOWN', 
                'UNKNWOWN', 'UNKONW', 'UNKOWN', 'UNSPECIFIED', 'UNITED STATES', 'US', 'CALIFORNIA', 'CA', ' ', '*NONE']

# POBOX keywords
pobox_keywords = "POBOX|PO BOX|P0 BOX|POSTAL|PO BX|9O BOX|OK BOX|P 0  BOX|P BOX|PB BOX|PI BOX|PIC BOX|P.O. BOX|" + \
                 "P.O.BOX|PIO BOX|PITZER BOX|PO B0X|PO BAX|PO BOS|PO BOT|PO BOV|POX BOX|SHOW BOX|POP BOX|P O BOX|POX BOX"

# Unknown phone numbers
unknown_numbers = ["0000000000", "1111111111", "2222222222", "3333333333", "4444444444", "5555555555", 
                   "6666666666", "7777777777", "8888888888", "9999999999", "0000000001"]

# Unknown email keywords
unknown_emails1 = "GENERATED|NOEMAIL|NOMAIL|REFUSE|UNKNOWN|NO@NO|NA@NA|PATIENT|" + \
                  "DOES NOT|MISSING|NONAME|DECLINED|ASK FOR|NOT GIVEN"
unknown_emails2 = ['NAGMAIL.COM', 'N', 'DECLINED', 'NA', 'NO', 'TEST', 'NONE', 'GOBACKTOASK']

# Unknown names
unknown_names1 = "NO FIRST NAME|NO INFO"
unknown_names2 = ["TEST", "PATIENT"]
#----

# Assuming invalid_addr1, invalid_addr2, ..., invalid_apt1, ..., etc. are lists
# Convert any string components to lists
invalid_addr1_list=invalid_addr1.split('|')
invalid_addr15_list=invalid_addr15.split('|')
pobox_keywords_list = pobox_keywords.split('|')
invalid_apt1_list = invalid_apt1.split('|')
unknown_emails1_list = unknown_emails1.split('|')
unknown_names1_list = unknown_names1.split('|')

# Combine all keywords into a single list
#all_invalid_keywords = invalid_addr1_list + invalid_addr15_list +invalid_addr3 + invalid_addr4 +\
#invalid_addr5 + invalid_apt1_list + invalid_apt2 + invalid_apt3 + pobox_keywords_list + unknown_numbers +\
#unknown_emails1_list +  unknown_emails2 + unknown_names1_list + unknown_names2

# Combine all keywords into a single list
# Ensure all keywords are strings and in uppercase for case-insensitive comparison
all_invalid_keywords = [str(keyword).upper() for keyword in ( invalid_addr1_list + invalid_addr15_list +invalid_addr3 + invalid_addr4 +\
invalid_addr5 + invalid_apt1_list + invalid_apt2 + invalid_apt3 + pobox_keywords_list + unknown_numbers +\
unknown_emails1_list +  unknown_emails2 + unknown_names1_list + unknown_names2)]

def check_invalid_component(parsed_addr, invalid_keywords):
    for component_type, component_value in parsed_addr.items():
        # Skip certain components from direct keyword matching
        if component_type in ['AddressNumber', 'AddressNumberPrefix', 'AddressNumberSuffix', 'StreetName', 'StreetNamePostType', 
                    'StreetNamePreDirectional','OccupancyType','OccupancyIdentifier','PlaceName','StreetNamePreType']:
            continue

        if any(keyword in component_value.upper() for keyword in invalid_keywords):
            print(f"Invalid component found: {component_type} -> {component_value}")
            return True
    return False

def clean_address(address, invalid_keywords):
    try:
        parsed_address, _ = usaddress.tag(address)
        if check_invalid_component(parsed_address, invalid_keywords):
            return ""  # Return empty string if invalid
        return address  # Return original address if valid
    except usaddress.RepeatedLabelError as e:
        print(f"Error parsing address '{address}': {e}")
        return ""

input_df2 = cleaned_df1



# Apply the cleaning function to the 'addr' field
input_df2['addr_valid'] = input_df2['addr'].apply(lambda x: clean_address(x, all_invalid_keywords))

#----
#Here we will do the same thing with the city, state and zipcodes i.e. compare them to the invalid keywords

# Define invalid keyword lists for city, state, and zipcode
invalid_city_keywords = invalid_addr4 # Add more as needed
invalid_state_keywords = invalid_addr3  # Add more as needed
invalid_zip_keywords = invalid_addr5  # Add more as needed

def check_invalid_component(parsed_addr, city_keywords, state_keywords, zip_keywords):
    is_invalid = False
    for component_type, component_value in parsed_addr.items():
        if component_type == 'PlaceName' and any(kw in component_value.upper() for kw in city_keywords):
            is_invalid = True
        elif component_type == 'StateName' and any(kw in component_value.upper() for kw in state_keywords):
            is_invalid = True
        elif component_type == 'ZipCode' and any(kw in component_value.upper() for kw in zip_keywords):  # Corrected key
            is_invalid = True
    return is_invalid

def clean_location(city, state, zipcode, city_keywords, state_keywords, zip_keywords):
    try:
        pseudo_address = f"{city}, {state} {zipcode}"  # Corrected variable name
        parsed_address, _ = usaddress.tag(pseudo_address)
        if check_invalid_component(parsed_address, city_keywords, state_keywords, zip_keywords):
            return "", "", ""  # Return empty strings if invalid
        return city, state, zipcode  # Return original values if valid
    except usaddress.RepeatedLabelError:
        print(f"Error parsing pseudo address '{city}, {state} {zipcode}'")
        return "", "", ""  # Handle parsing errors

# Apply the function (assuming input_df2 is defined)
input_df2[['city_valid', 'state_valid', 'zip_valid']] = input_df2.apply(
    lambda row: clean_location(row['city'], row['state'], row['zip'],
                               invalid_city_keywords, invalid_state_keywords, invalid_zip_keywords),
    axis=1, result_type='expand')

#----
#I need to also do the same thing for the apt field
# Define your list of invalid keywords for apartment numbers
invalid_apt_keywords = invalid_addr5  # Add your keywords

def is_valid_apt(apt, invalid_keywords):
    # Check if the apartment number is in the invalid keywords
    if any(kw.lower() in apt.lower() for kw in invalid_keywords):
        return ""
    return apt

# Apply the function to the 'PER_Apartment' field
input_df2['apt_valid'] = input_df2['PER_Apartment'].apply(lambda x: is_valid_apt(x, invalid_apt_keywords))

#----
apt_keywords = ['Apt', 'Unit', 'Suite', 'Bldg', 'Room', 'Fl', '#']

# Regular expression pattern for extracting apartment/unit numbers
apt_pattern = r'\b(?:' + '|'.join(apt_keywords) + r')\s*\S+'

def extract_apt(addr):
    match = re.search(apt_pattern, addr, re.IGNORECASE)
    return match.group(0) if match else ""

# Extract and populate the apt_valid field
input_df2['apt_valid'] = input_df2['addr_valid'].apply(extract_apt)
#----
#I am sure that there is an easier way of doing what I did above but it seems to work the way Tinas code worked
#----

def clean_repeat_char(df, var, repeat_num=0):
    # Create a regular expression for repeated characters
    repeat_char_regex = r"^(.)\1*$"

    # Identify rows with invalid data
    df['invalid'] = df[var].apply(lambda x: (bool(re.match(repeat_char_regex, x)) and len(x) > repeat_num) or x in ["0", "00"])

    # Replace invalid data with an empty string
    df[var + '_new'] = df.apply(lambda row: "" if row['invalid'] else row[var], axis=1)

    return df

# Assuming cleaned_df2 is your DataFrame and it already has an 'apt_valid' column
# If not, you need to create it before applying the function
# For example:
# cleaned_df2['apt_valid'] = ...

cleaned_df3 = input_df2
cleaned_df3 = clean_repeat_char(input_df2, "addr_valid")
cleaned_df3 = clean_repeat_char(cleaned_df3, "apt_valid", repeat_num=3)
cleaned_df3 = clean_repeat_char(cleaned_df3, "city_valid")
cleaned_df3 = clean_repeat_char(cleaned_df3, "state_valid")
cleaned_df3 = clean_repeat_char(cleaned_df3, "zip_valid")

# Update original columns with the cleaned data
cleaned_df3['addr_valid'] = cleaned_df3['addr_valid_new']
cleaned_df3['apt_valid'] = cleaned_df3['apt_valid_new']
cleaned_df3['city_valid'] = cleaned_df3['city_valid_new']
cleaned_df3['state_valid'] = cleaned_df3['state_valid_new']
cleaned_df3['zip_valid'] = cleaned_df3['zip_valid_new']

# Drop the temporary columns
cleaned_df3.drop(columns=['invalid', 'addr_valid_new', 'apt_valid_new', 'city_valid_new', 'state_valid_new', 'zip_valid_new'], inplace=True)

#----
def clean_spec_char(df, var):
    # Define a regex pattern that checks for the absence of alphanumeric characters
    spec_char_regex = r"^[^a-zA-Z\d]+$"

    # Identify rows with only special characters and mark them as invalid
    df['invalid'] = df[var].apply(lambda x: bool(re.match(spec_char_regex, x)) if pd.notna(x) else False)

    # Replace invalid data with an empty string
    df['new_' + var] = df.apply(lambda row: "" if row['invalid'] else row[var], axis=1)

    return df

# Apply the function to the DataFrame
# Assume cleaned_df3 is your existing DataFrame
cleaned_df4 = clean_spec_char(cleaned_df3, "addr_valid")
cleaned_df4['addr_valid'] = cleaned_df4['new_addr_valid']
cleaned_df4 = clean_spec_char(cleaned_df4, "apt_valid")
cleaned_df4['apt_valid'] = cleaned_df4['new_apt_valid']
cleaned_df4 = clean_spec_char(cleaned_df4, "city_valid")
cleaned_df4['city_valid'] = cleaned_df4['new_city_valid']
cleaned_df4 = clean_spec_char(cleaned_df4, "state_valid")
cleaned_df4['state_valid'] = cleaned_df4['new_state_valid']
cleaned_df4 = clean_spec_char(cleaned_df4, "zip_valid")
cleaned_df4['zip_valid'] = cleaned_df4['new_zip_valid']

# Drop the temporary columns
cleaned_df4.drop(columns=['invalid', 'new_addr_valid', 'new_apt_valid', 'new_city_valid', 'new_state_valid', 'new_zip_valid'], inplace=True)

#----
def clean_num_only(df, var):
    # Remove all non-alphanumeric characters and check if the remaining string is numeric
    df['invalid'] = df[var].apply(lambda x: x.isalnum() and x.isdigit() if pd.notna(x) else False)

    # Replace invalid data with an empty string
    df['new_' + var] = df.apply(lambda row: "" if row['invalid'] else row[var], axis=1)

    return df

# Apply the function to the DataFrame
# Assume cleaned_df4 is your existing DataFrame
cleaned_df5 = clean_num_only(cleaned_df4, "addr_valid")
cleaned_df5['addr_valid'] = cleaned_df5['new_addr_valid']
cleaned_df5 = clean_num_only(cleaned_df5, "city_valid")
cleaned_df5['city_valid'] = cleaned_df5['new_city_valid']
cleaned_df5 = clean_num_only(cleaned_df5, "state_valid")
cleaned_df5['state_valid'] = cleaned_df5['new_state_valid']

# Drop the temporary columns
cleaned_df5.drop(columns=['invalid', 'new_addr_valid', 'new_city_valid', 'new_state_valid'], inplace=True)
cleaned_df5
#----

def remove_email(df, var):
    # Define a regex pattern for email addresses
    email_regex = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"

    # Identify rows with email addresses and mark them as invalid
    df['invalid'] = df[var].apply(lambda x: bool(re.search(email_regex, x)) if pd.notna(x) else False)

    # Replace invalid data with an empty string
    df['new_' + var] = df.apply(lambda row: "" if row['invalid'] else row[var], axis=1)

    return df

# Example usage
# Assume you have a DataFrame named 'your_df' with a column 'original_address'
# your_df = pd.DataFrame(...) # your actual DataFrame
cleaned_df6 = remove_email(cleaned_df5, "PER_Email")
#cleaned_df6['original_address'] = cleaned_df6['new_original_address']
#cleaned_df.drop(columns=['invalid', 'new_original_address'], inplace=True)

#----
def clean_dates_only(df, var):
    # Define regex patterns for date formats
    date_patterns = [
        r"\d{2}/\d{2}/\d{4}",  # mm/dd/yyyy
        r"\d{2}/\d{2}/\d{2}",  # mm/dd/yy
        r"\d{2}-\d{2}-\d{4}",  # mm-dd-yyyy
        r"\d{2}-\d{2}-\d{2}"   # mm-dd-yy
    ]

    # Combine patterns into a single regex
    combined_pattern = '|'.join(date_patterns)

    # Identify rows with date-like strings
    df['invalid'] = df[var].apply(lambda x: bool(re.search(combined_pattern, x)) if pd.notna(x) else False)

    # Replace invalid data with an empty string
    df['new_' + var] = df.apply(lambda row: "" if row['invalid'] else row[var], axis=1)

    return df

# Apply the function to the DataFrame
# Assume cleaned_df6 is your existing DataFrame
cleaned_df7 = clean_dates_only(cleaned_df6, "addr_valid") ## we only limited it to the address components need to use df5 instead of df6
cleaned_df7['addr_valid'] = cleaned_df7['new_addr_valid']
cleaned_df7 = clean_dates_only(cleaned_df7, "apt_valid")
cleaned_df7['apt_valid'] = cleaned_df7['new_apt_valid']
cleaned_df7 = clean_dates_only(cleaned_df7, "city_valid")
cleaned_df7['city_valid'] = cleaned_df7['new_city_valid']
cleaned_df7 = clean_dates_only(cleaned_df7, "state_valid")
cleaned_df7['state_valid'] = cleaned_df7['new_state_valid']
cleaned_df7 = clean_dates_only(cleaned_df7, "zip_valid")
cleaned_df7['zip_valid'] = cleaned_df7['new_zip_valid']

# Drop the temporary columns
cleaned_df7.drop(columns=['invalid', 'new_addr_valid', 'new_apt_valid', 'new_city_valid', 'new_state_valid', 'new_zip_valid'], inplace=True)

#----
def clean_two_word(df, var):
    street_suffix = ["RD", "ST", "ROAD", "STREET", "PL", "PLACE", "LN", "LANE", "UPDATE", "OTHER"]
    
    def is_invalid(address):
        if pd.isna(address):
            return False
        words = re.sub(r"[^a-zA-Z0-9\s]", "", address.replace("  ", " ")).split()
        if len(words) != 2:
            return False
        return (words[1] in street_suffix and 
                bool(re.match(r"^(.)\1*$", words[0])) and 
                len(words[0]) > 1) or (words[0].replace("0", "") == "")

    df['invalid'] = df[var].apply(is_invalid)

    # Replace invalid data with an empty string
    df['new_' + var] = df.apply(lambda row: "" if row['invalid'] else row[var], axis=1)

    return df
#----

# Apply the function to the DataFrame
# Assume cleaned_df7 is your existing DataFrame
cleaned_df8 = clean_two_word(cleaned_df7, "addr_valid")
cleaned_df8['addr_valid'] = cleaned_df8['new_addr_valid']
cleaned_df8 = clean_two_word(cleaned_df8, "apt_valid")
cleaned_df8['apt_valid'] = cleaned_df8['new_apt_valid']
cleaned_df8 = clean_two_word(cleaned_df8, "city_valid")
cleaned_df8['city_valid'] = cleaned_df8['new_city_valid']
cleaned_df8 = clean_two_word(cleaned_df8, "state_valid")
cleaned_df8['state_valid'] = cleaned_df8['new_state_valid']
cleaned_df8 = clean_two_word(cleaned_df8, "zip_valid")
cleaned_df8['zip_valid'] = cleaned_df8['new_zip_valid']

# Drop the temporary columns
cleaned_df8.drop(columns=['invalid', 'new_addr_valid', 'new_apt_valid', 'new_city_valid', 'new_state_valid', 'new_zip_valid'], inplace=True)

#----
def unit_parse(df, var):
    # List of apartment keywords
    apt_names_st = ['APT', 'APP', 'AP', 'APACE', 'APARTMENT', 'CONDO', 'NO', 'STE', 'SUITE', 'SPC', 'UNIT', 
                    'BUILD', 'BLDG', 'BUILDING', 'RM', 'ROOM']

    # Create regex pattern for extracting unit
    apt_pattern_out = r"(?i)\b(" + "|".join(apt_names_st) + r")\s*\#?\s*[\d\w]+"

    # Function to extract unit
    def extract_unit(address):
        match = re.search(apt_pattern_out, address)
        return match.group(0) if match else ''

    # Function to remove unit
    def remove_unit(address):
        return re.sub(apt_pattern_out, '', address).strip()

    # Apply the functions to create new columns
    df['new_address'] = df[var].apply(remove_unit)
    df['new_address_unit'] = df[var].apply(extract_unit)

    return df


cleaned_df9 = unit_parse(cleaned_df8, "addr_valid")

print(f"Execution time: {time.time() - start_time}")
# Out:
# Requirement already satisfied: pyodbc in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (5.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: duckdb in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (0.9.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: splink in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (3.9.12)
# Requirement already satisfied: Jinja2>=3.0.3 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (3.1.3)
# Requirement already satisfied: altair<6.0.0,>=5.0.1 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (5.2.0)
# Requirement already satisfied: duckdb>=0.8.0 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (0.9.2)
# Requirement already satisfied: jsonschema<5.0,>=3.2 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (4.21.1)
# Requirement already satisfied: pandas>1.3.0 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (2.2.0)
# Requirement already satisfied: phonetics<2.0.0,>=1.0.5 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (1.0.5)
# Requirement already satisfied: sqlglot<19.0.0,>=13.0.0 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from splink) (18.17.0)
# Requirement already satisfied: numpy in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from altair<6.0.0,>=5.0.1->splink) (1.26.3)
# Requirement already satisfied: packaging in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from altair<6.0.0,>=5.0.1->splink) (23.2)
# Requirement already satisfied: toolz in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from altair<6.0.0,>=5.0.1->splink) (0.12.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from Jinja2>=3.0.3->splink) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema<5.0,>=3.2->splink) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema<5.0,>=3.2->splink) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema<5.0,>=3.2->splink) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from jsonschema<5.0,>=3.2->splink) (0.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from pandas>1.3.0->splink) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from pandas>1.3.0->splink) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from pandas>1.3.0->splink) (2023.4)
# Requirement already satisfied: six>=1.5 in ./miniforge3/envs/tomenv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>1.3.0->splink) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Execution time: 0.00024366378784179688
# Error parsing address '1227 1 8 W 91ST ST':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1227 1 8 W 91ST ST
# PARSED TOKENS:    [('1227', 'AddressNumber'), ('1', 'StreetName'), ('8', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('91ST', 'StreetName'), ('ST', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> W
# Error parsing address '371 N  N AVENUE 52':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  371 N  N AVENUE 52
# PARSED TOKENS:    [('371', 'AddressNumber'), ('N', 'StreetNamePreDirectional'), ('N', 'StreetName'), ('AVENUE', 'StreetNamePreType'), ('52', 'StreetName')]
# UNCERTAIN LABEL:  StreetName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> N
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> N
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> S
# Invalid component found: StreetNamePostDirectional -> N N
# Invalid component found: StreetNamePostDirectional -> S
# Error parsing address '3255 E E AVENUE R SPC 137':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  3255 E E AVENUE R SPC 137
# PARSED TOKENS:    [('3255', 'AddressNumber'), ('E', 'StreetNamePreDirectional'), ('E', 'StreetName'), ('AVENUE', 'StreetNamePostType'), ('R', 'OccupancyIdentifier'), ('SPC', 'OccupancyType'), ('137', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> S
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StateName -> PK
# Invalid component found: StreetNamePostDirectional -> W
# Error parsing address '2059 E E AVENUE I SPC 1A':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  2059 E E AVENUE I SPC 1A
# PARSED TOKENS:    [('2059', 'AddressNumber'), ('E', 'StreetNamePreDirectional'), ('E', 'StreetName'), ('AVENUE', 'StreetNamePostType'), ('I', 'OccupancyIdentifier'), ('SPC', 'OccupancyType'), ('1A', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  OccupancyIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StateName -> BL
# Invalid component found: StateName -> HC
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: BuildingName -> C O COMMON GROUN
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StateName -> PT
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: ZipCode -> 90027
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StateName -> PT
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: ZipCode -> 91331
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> S
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Error parsing address '1008 E 1 4 E 18TH ST':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1008 E 1 4 E 18TH ST
# PARSED TOKENS:    [('1008', 'AddressNumber'), ('E', 'StreetNamePreDirectional'), ('1', 'StreetName'), ('4', 'AddressNumber'), ('E', 'StreetNamePreDirectional'), ('18TH', 'StreetName'), ('ST', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StateName -> BL
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: ZipCode -> 91652
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: ZipCode -> 91770
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> S
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: ZipCode -> 20355
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StateName -> RHB
# Error parsing address '5520 N 190TH ST 18':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  5520 N 190TH ST 18
# PARSED TOKENS:    [('5520', 'AddressNumber'), ('N', 'StreetNamePreDirectional'), ('190TH', 'StreetName'), ('ST', 'StreetNamePreType'), ('18', 'StreetName')]
# UNCERTAIN LABEL:  StreetName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: ZipCode -> 91331
# Invalid component found: SubaddressIdentifier -> 1515
# Invalid component found: StreetNamePostDirectional -> E
# Error parsing address '3300 15TH ST W SPC 56':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  3300 15TH ST W SPC 56
# PARSED TOKENS:    [('3300', 'AddressNumber'), ('15TH', 'StreetName'), ('ST', 'StreetNamePostType'), ('W', 'StreetNamePostDirectional'), ('SPC', 'StreetNamePreType'), ('56', 'StreetName')]
# UNCERTAIN LABEL:  StreetName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: ZipCode -> 91331
# Invalid component found: StreetNamePostDirectional -> S
# Invalid component found: ZipCode -> 90731
# Invalid component found: ZipCode -> 90731
# Invalid component found: ZipCode -> 90731
# Invalid component found: ZipCode -> 90731
# Invalid component found: ZipCode -> 90731
# Invalid component found: ZipCode -> 90731
# Error parsing address '1437 N N AVENUE 47':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1437 N N AVENUE 47
# PARSED TOKENS:    [('1437', 'AddressNumber'), ('N', 'StreetNamePreDirectional'), ('N', 'StreetName'), ('AVENUE', 'StreetNamePreType'), ('47', 'StreetName')]
# UNCERTAIN LABEL:  StreetName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: ZipCode -> 90731
# Invalid component found: ZipCode -> 90731
# Invalid component found: StreetNamePostDirectional -> N
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> S
# Error parsing address '246 1 2 W  91 ST':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  246 1 2 W  91 ST
# PARSED TOKENS:    [('246', 'AddressNumber'), ('1', 'StreetName'), ('2', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('91', 'StreetName'), ('ST', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '117 S S AVENUE 54 APT 3':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  117 S S AVENUE 54 APT 3
# PARSED TOKENS:    [('117', 'AddressNumber'), ('S', 'StreetNamePreDirectional'), ('S', 'StreetName'), ('AVENUE', 'StreetNamePreType'), ('54', 'StreetName'), ('APT', 'OccupancyType'), ('3', 'OccupancyIdentifier')]
# UNCERTAIN LABEL:  StreetName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> N
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: ZipCode -> 90806
# Error parsing address '4639 W 17 ST 17 ST':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  4639 W 17 ST 17 ST
# PARSED TOKENS:    [('4639', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('17', 'StreetName'), ('ST', 'StreetNamePreType'), ('17', 'StreetName'), ('ST', 'StreetNamePostType')]
# UNCERTAIN LABEL:  StreetName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> E
# Error parsing address '1244 N ORANGE DR  2 UTL PT':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1244 N ORANGE DR  2 UTL PT
# PARSED TOKENS:    [('1244', 'AddressNumber'), ('N', 'StreetNamePreDirectional'), ('ORANGE', 'StreetName'), ('DR', 'StreetNamePostType'), ('2', 'AddressNumber'), ('UTL', 'StreetName'), ('PT', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: Recipient -> REFUSED TO ANS SOME QUES
# Invalid component found: ZipCode -> 90028
# Invalid component found: StreetNamePostDirectional -> N
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: ZipCode -> 91342
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: ZipCode -> 90066
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: Recipient -> 466 COLONIA DE LAS PALMAS TRANS TO ELA
# Invalid component found: StateName -> ST
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StateName -> BL
# Invalid component found: ZipCode -> 91331
# Error parsing address '639 S S AVENUE 60':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  639 S S AVENUE 60
# PARSED TOKENS:    [('639', 'AddressNumber'), ('S', 'StreetNamePreDirectional'), ('S', 'StreetName'), ('AVENUE', 'StreetNamePreType'), ('60', 'StreetName')]
# UNCERTAIN LABEL:  StreetName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> BL
# Invalid component found: StreetNamePostDirectional -> S
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StateName -> PL
# Invalid component found: StreetNamePostDirectional -> N
# Error parsing address '2117 W W AVENUE 30':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  2117 W W AVENUE 30
# PARSED TOKENS:    [('2117', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('W', 'StreetName'), ('AVENUE', 'StreetNamePreType'), ('30', 'StreetName')]
# UNCERTAIN LABEL:  StreetName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StateName -> PL
# Invalid component found: USPSBoxType -> SP
# Invalid component found: StreetNamePostDirectional -> W
# Error parsing address '1022 1 4 W 64TH ST':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1022 1 4 W 64TH ST
# PARSED TOKENS:    [('1022', 'AddressNumber'), ('1', 'StreetName'), ('4', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('64TH', 'StreetName'), ('ST', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> S
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> S
# Invalid component found: ZipCode -> 91331
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StateName -> NO GOOD
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: ZipCode -> 90731
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Error parsing address '1335 E 1 4 E 42ND PL':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1335 E 1 4 E 42ND PL
# PARSED TOKENS:    [('1335', 'AddressNumber'), ('E', 'StreetNamePreDirectional'), ('1', 'StreetName'), ('4', 'AddressNumber'), ('E', 'StreetNamePreDirectional'), ('42ND', 'StreetName'), ('PL', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: ZipCode -> 91331
# Error parsing address '1817 N N AVENUE 55':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1817 N N AVENUE 55
# PARSED TOKENS:    [('1817', 'AddressNumber'), ('N', 'StreetNamePreDirectional'), ('N', 'StreetName'), ('AVENUE', 'StreetNamePreType'), ('55', 'StreetName')]
# UNCERTAIN LABEL:  StreetName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Error parsing address '145 1 4 E 223RD ST':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  145 1 4 E 223RD ST
# PARSED TOKENS:    [('145', 'AddressNumber'), ('1', 'StreetName'), ('4', 'AddressNumber'), ('E', 'StreetNamePreDirectional'), ('223RD', 'StreetName'), ('ST', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '338 S S AVENUE 60':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  338 S S AVENUE 60
# PARSED TOKENS:    [('338', 'AddressNumber'), ('S', 'StreetNamePreDirectional'), ('S', 'StreetName'), ('AVENUE', 'StreetNamePreType'), ('60', 'StreetName')]
# UNCERTAIN LABEL:  StreetName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: IntersectionSeparator -> GRP
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> N
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> S S
# Invalid component found: StreetNamePostDirectional -> W
# Error parsing address '1747  N KINGSLEY DR  2 UTL PT':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1747  N KINGSLEY DR  2 UTL PT
# PARSED TOKENS:    [('1747', 'AddressNumber'), ('N', 'StreetNamePreDirectional'), ('KINGSLEY', 'StreetName'), ('DR', 'StreetNamePostType'), ('2', 'AddressNumber'), ('UTL', 'StreetName'), ('PT', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '5321 1 4 S VAN NESS AVE':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  5321 1 4 S VAN NESS AVE
# PARSED TOKENS:    [('5321', 'AddressNumber'), ('1', 'StreetName'), ('4', 'AddressNumber'), ('S', 'StreetNamePreDirectional'), ('VAN', 'StreetName'), ('NESS', 'StreetName'), ('AVE', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Error parsing address '1501 PALOS VERDES DR N SPC 32':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1501 PALOS VERDES DR N SPC 32
# PARSED TOKENS:    [('1501', 'AddressNumber'), ('PALOS', 'StreetName'), ('VERDES', 'StreetName'), ('DR', 'StreetNamePostType'), ('N', 'StreetNamePostDirectional'), ('SPC', 'StreetNamePreType'), ('32', 'StreetName')]
# UNCERTAIN LABEL:  StreetName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> N
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Error parsing address '337 1 4 N HELIOTROPE DR':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  337 1 4 N HELIOTROPE DR
# PARSED TOKENS:    [('337', 'AddressNumber'), ('1', 'StreetName'), ('4', 'AddressNumber'), ('N', 'StreetNamePreDirectional'), ('HELIOTROPE', 'StreetName'), ('DR', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StateName -> PL
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> E
# Error parsing address '3811 W 1 4 W ADAMS BLVD':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  3811 W 1 4 W ADAMS BLVD
# PARSED TOKENS:    [('3811', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('1', 'StreetName'), ('4', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('ADAMS', 'StreetName'), ('BLVD', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> S
# Invalid component found: ZipCode -> 91343
# Invalid component found: StreetNamePostDirectional -> E
# Invalid component found: StreetNamePostDirectional -> W
# Invalid component found: SubaddressType -> BLDG
# Invalid component found: StreetNamePostDirectional -> W
# Error parsing address '247 1 4 W 71ST ST':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  247 1 4 W 71ST ST
# PARSED TOKENS:    [('247', 'AddressNumber'), ('1', 'StreetName'), ('4', 'AddressNumber'), ('W', 'StreetNamePreDirectional'), ('71ST', 'StreetName'), ('ST', 'StreetNamePostType')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Invalid component found: StreetNamePostDirectional -> E
# Execution time: 6.2480690479278564

# %%
cleaned_df9
# Out:
#      SynchronizationTimestamp  Status PER_SiteCode  PER_RowID  PER_RootID  \
# 0     2023-03-27 13:20:14.570    True        10100     679027      679027
# 1     2023-03-27 13:20:14.570    True        10100     679030      679030
# 2     2023-03-27 13:20:14.570    True        10100     679052      679052
# 3     2023-03-27 13:20:14.570    True        10100     679088      679088
# 4     2023-03-27 13:20:14.570    True        10100     679142      679142
# ...                       ...     ...          ...        ...         ...
# 9995  2023-03-27 13:20:52.220    True        10100     698752      698752
# 9996  2023-03-27 13:20:52.220    True        10100     698759      698759
# 9997  2023-03-27 13:20:52.220    True        10100     698793      698793
# 9998  2023-03-27 13:20:52.220    True        10100     698816      698816
# 9999  2023-03-27 13:20:52.220    True        10100     698819      698819
#
#       PER_ClientID          PER_CreateDate PER_UpdateDate  PER_IsPatient  \
# 0           438816 2000-07-06 00:00:00.000     2000-07-06           True
# 1           438819 2000-04-27 00:00:00.000     2000-04-27           True
# 2           438841 2000-07-06 00:00:00.000     2000-07-06           True
# 3           438875 2016-10-28 10:38:40.587     2000-04-27           True
# 4           438923 2000-07-06 00:00:00.000     2000-07-06          False
# ...            ...                     ...            ...            ...
# 9995        457502 2020-10-10 22:41:59.150     2000-09-07           True
# 9996        457509 2000-09-07 00:00:00.000     2000-09-07          False
# 9997        457542 2000-09-07 00:00:00.000     2000-09-07           True
# 9998        457565 2000-04-27 00:00:00.000     2000-04-27           True
# 9999        457568 2000-04-27 00:00:00.000     2000-04-27           True
#
#       PER_IsContact  ...  state    zip                          addr_valid  \
# 0             False  ...     CA  91768                     734 ILLINOIS ST
# 1             False  ...     CA  90249                    15238 ARDATH AVE
# 2             False  ...     CA  91405           14757 SHERMAN WAY APT 122
# 3             False  ...     CA  90065                       3032 TATUM ST
# 4             False  ...     CA  90242               11914 BELLFLOWER BLVD
# ...             ...  ...    ...    ...                                 ...
# 9995          False  ...     CA  90008                  3941 ARLINGTON AVE
# 9996          False  ...     CA  91601                      5245 DENNY AVE
# 9997          False  ...     CA  90057  323 S S LA FAYETTE PARK PL APT 339
# 9998          False  ...     CA  91602                4445 TUJUNGA AVE   2
# 9999          False  ...     CA  90022                   4377 NEW YORK AVE
#
#            city_valid state_valid zip_valid apt_valid new_PER_Email  \
# 0                                                              None
# 1                                                              None
# 2            VAN NUYS          CA     91405   APT 122          None
# 3         Los Angeles          CA     90065
# 4              Downey          CA     90242                    None
# ...               ...         ...       ...       ...           ...
# 9995      Los Angeles          CA     90008
# 9996  North Hollywood          CA     91601                    None
# 9997      LOS ANGELES          CA     90057   APT 339          None
# 9998  NORTH HOLLYWOOD          CA     91602                    None
# 9999      LOS ANGELES          CA     90022                    None
#
#                      new_address new_address_unit
# 0                734 ILLINOIS ST
# 1               15238 ARDATH AVE
# 2              14757 SHERMAN WAY          APT 122
# 3                  3032 TATUM ST
# 4          11914 BELLFLOWER BLVD
# ...                          ...              ...
# 9995          3941 ARLINGTON AVE
# 9996              5245 DENNY AVE
# 9997  323 S S LA FAYETTE PARK PL          APT 339
# 9998        4445 TUJUNGA AVE   2
# 9999           4377 NEW YORK AVE
#
# [10000 rows x 97 columns]

# %%
cleaned_df9.columns
# Out:
# Index(['SynchronizationTimestamp', 'Status', 'PER_SiteCode', 'PER_RowID',
#        'PER_RootID', 'PER_ClientID', 'PER_CreateDate', 'PER_UpdateDate',
#        'PER_IsPatient', 'PER_IsContact', 'PER_IsFamilyMember', 'PER_IsPrimary',
#        'PER_IsVersion', 'PER_LastName', 'PER_FirstName', 'PER_MiddleName',
#        'PER_ThirdName', 'PER_FourthName', 'PER_NameSuffix', 'PER_NamePrefix',
#        'PER_SSN', 'PER_DOB', 'PER_PrimaryLanguage', 'PER_Age', 'PER_Ethnicity',
#        'PER_ReportedRace', 'PER_DateOfUSArrival', 'PER_Sex',
#        'PER_MaritalStatus', 'PER_StateNumber', 'PER_ResidenceCounty',
#        'PER_CountryofResidence', 'PER_CountryofBirth',
#        'PER_PrimaryNationality', 'PER_ParentOrGuardianName',
#        'PER_LastNameAlphaUp', 'PER_FirstNameAlphaUp', 'PER_DOD',
#        'PER_DeceasedStatus', 'PER_StatusFlag', 'PER_StreetAddress',
#        'PER_Apartment', 'PER_City', 'PER_State', 'PER_Zip', 'PER_CensusTract',
#        'PER_Latitude', 'PER_Longitude', 'PER_AddressStandardized',
#        'PER_CountyFIPS', 'PER_County', 'PER_CensusBlock', 'PER_ZipPlus4',
#        'PER_HomePhone', 'PER_CellularPhoneOrPager',
#        'PER_WorkOrSchoolTelephone', 'PER_Email',
#        'PER_OtherElectronicContactInformation', 'PER_WorkOrSchoolLocation',
#        'PER_WorkOrSchoolContact', 'PER_OccupationSettingType',
#        'PER_OccupationSettingTypeSpecify', 'PER_Occupation',
#        'PER_OccupationSpecify', 'PER_OccupationLocation',
#        'PER_HomePhoneAlphaUp', 'PER_WorkSchoolPhoneAlphaUp', 'PER_FolderID',
#        'PER_CaseActID', 'PER_PrimaryLanguageDR', 'PER_EthnicityDR',
#        'PER_ReportedRaceDR', 'PER_SexDR', 'PER_MaritalStatusDR',
#        'PER_ResidenceCountyDR', 'PER_CountryofResidenceDR',
#        'PER_CountryofBirthDR', 'PER_PrimaryNationalityDR',
#        'PER_DeceasedStatusDR', 'PER_StatusFlagDR',
#        'PER_WorkOrSchoolLocationDR', 'PER_OccupationSettingTypeDR',
#        'PER_OccupationDR', 'id', 'addr_frac', 'addr', 'city', 'state', 'zip',
#        'addr_valid', 'city_valid', 'state_valid', 'zip_valid', 'apt_valid',
#        'new_PER_Email', 'new_address', 'new_address_unit'],
#       dtype='object')

# %%
#The blockers that Tina uses are:fname, mname, lname, dob, phn1, phn2, email, ssn, and addr_var

#'PER_LastName', 'PER_FirstName', 'PER_MiddleName',  'PER_SSN', 'PER_DOB',  'PER_HomePhone', 'PER_CellularPhoneOrPager',
#        'PER_Email'
    
cleaned_df9_subset=cleaned_df9[['PER_LastName', 'PER_FirstName', 'PER_MiddleName',  'PER_SSN', 'PER_DOB',  'PER_HomePhone', 'PER_CellularPhoneOrPager',
        'PER_Email', 'city_valid', 'state_valid',
       'zip_valid', 'apt_valid', 'new_address', 'new_address_unit', 'id']]

# %%
#Feature engineering for RecordLinkage/Deduplication

import pandas as pd
import phonetics

# Define a function to apply the dmetaphone phonetic algorithm to each name in the column
def dmetaphone_name(name):
    if name is None:
        pass
    else:
        return phonetics.dmetaphone(name)

# Apply the function to the "first_name", lastname and middlename columns using the apply method
cleaned_df9_subset['firstname_dm'] = cleaned_df9_subset['PER_FirstName'].apply(dmetaphone_name)
cleaned_df9_subset['lastname_dm'] = cleaned_df9_subset['PER_LastName'].apply(dmetaphone_name)
cleaned_df9_subset['middlename_dm'] = cleaned_df9_subset['PER_MiddleName'].apply(dmetaphone_name)


# Create a new column "full_name" by combining "first_name" and "surname" columns
cleaned_df9_subset['full_name'] = cleaned_df9_subset['PER_FirstName'] + ' ' + cleaned_df9_subset['PER_LastName']
# Out:
# /tmp/ipykernel_13298/1784819825.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df9_subset['firstname_dm'] = cleaned_df9_subset['PER_FirstName'].apply(dmetaphone_name)
# /tmp/ipykernel_13298/1784819825.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df9_subset['lastname_dm'] = cleaned_df9_subset['PER_LastName'].apply(dmetaphone_name)
# /tmp/ipykernel_13298/1784819825.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df9_subset['middlename_dm'] = cleaned_df9_subset['PER_MiddleName'].apply(dmetaphone_name)
# /tmp/ipykernel_13298/1784819825.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df9_subset['full_name'] = cleaned_df9_subset['PER_FirstName'] + ' ' + cleaned_df9_subset['PER_LastName']

# %%
cleaned_df9_subset.columns
# Out:
# Index(['PER_LastName', 'PER_FirstName', 'PER_MiddleName', 'PER_SSN', 'PER_DOB',
#        'PER_HomePhone', 'PER_CellularPhoneOrPager', 'PER_Email', 'city_valid',
#        'state_valid', 'zip_valid', 'apt_valid', 'new_address',
#        'new_address_unit', 'id', 'firstname_dm', 'lastname_dm',
#        'middlename_dm', 'full_name'],
#       dtype='object')

# %%
counts = cleaned_df9_subset.isna().sum()
print(counts.sort_values())
# Out:
# PER_LastName                   0
# lastname_dm                    0
# firstname_dm                   0
# id                             0
# new_address_unit               0
# new_address                    0
# apt_valid                      0
# zip_valid                      0
# state_valid                    0
# PER_SSN                        0
# PER_FirstName                  0
# city_valid                     0
# full_name                      0
# PER_DOB                      198
# PER_HomePhone               1832
# middlename_dm               6400
# PER_MiddleName              6400
# PER_Email                   7853
# PER_CellularPhoneOrPager    7853
# dtype: int64

# %%
from splink.duckdb.linker import DuckDBLinker
#from splink.spark.linker import SparkLinker

settings = {
    "unique_id_column_name": "id",
    "link_type": "dedupe_only",
}

linker = DuckDBLinker(cleaned_df9_subset, settings)

# %%
from splink.duckdb.blocking_rule_library import block_on

blocking_rules = [
        block_on("lastname_dm"),
        block_on("PER_LastName"),
        block_on("new_address"),
        block_on("full_name"),
        block_on("firstname_dm"),
        block_on("PER_FirstName"),
        block_on("PER_DOB"),
        block_on("zip_valid"),
        block_on("PER_HomePhone"),
        block_on("PER_Email"),
        block_on("PER_CellularPhoneOrPager"),
        block_on("middlename_dm"),
        block_on("PER_SSN")
]
linker.cumulative_num_comparisons_from_blocking_rules_chart(blocking_rules)
# Out:
# alt.Chart(...)

# %%
#so it look like ssn requires too many comparisons (the documentation says to keep it down to 20 million or less to run fast on a laptop). If we run it on spark, it wont matter as much..

# %%
from splink.duckdb.blocking_rule_library import block_on

blocking_rules = [
        block_on("lastname_dm"),
        block_on("PER_LastName"),
        block_on("new_address"),
        #block_on("full_name"),
        block_on("firstname_dm"),
        block_on("PER_FirstName"),
        block_on("PER_DOB"),
        block_on("zip_valid"),
        block_on("PER_HomePhone"),
        block_on("PER_Email"),
        block_on("PER_CellularPhoneOrPager"),
        block_on("middlename_dm")
]

# %%
import splink.duckdb.comparison_template_library as ctl
from splink.duckdb.linker import DuckDBLinker
import splink.duckdb.comparison_library as cl


import splink.duckdb.comparison_library as cl
import splink.duckdb.comparison_template_library as ctl


settings = {
    "unique_id_column_name": "id",
    "link_type": "dedupe_only",
    "blocking_rules_to_generate_predictions": blocking_rules,
    "comparisons": [
        ctl.name_comparison("PER_FirstName"),
        ctl.name_comparison("PER_LastName"),
        ctl.name_comparison("full_name"),
        ctl.email_comparison("PER_Email", include_username_fuzzy_level=False),
        ctl.forename_surname_comparison("PER_FirstName","PER_LastName"),
        cl.levenshtein_at_thresholds("PER_SSN", [2]),
        cl.exact_match("new_address", term_frequency_adjustments=True),
        ctl.date_comparison("PER_DOB"),
    ],
    "retain_intermediate_calculation_columns": True
}

linker = DuckDBLinker(cleaned_df9_subset, settings, set_up_basic_logging=False)
deterministic_rules = [
    "l.PER_SSN = r.PER_SSN and l.PER_DOB = r.PER_DOB",
    "l.PER_FirstName = r.PER_FirstName and l.PER_DOB = r.PER_DOB",
    "l.PER_LastName = r.PER_LastName and l.PER_DOB = r.PER_DOB",
]

linker.estimate_probability_two_random_records_match(deterministic_rules, recall=0.6)
# Out:
# Probability two random records match is estimated to be  5.7e-05.
# This means that amongst all possible pairwise record comparisons, one in 17,531.85 are expected to match.  With 49,995,000 total possible comparisons, we expect a total of around 2,851.67 matching pairs

# %%
linker.estimate_u_using_random_sampling(max_pairs=1e8)
# Out:
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - PER_FirstName (no m values are trained).
#     - PER_LastName (no m values are trained).
#     - full_name (no m values are trained).
#     - PER_Email (no m values are trained).
#     - custom_PER_LastName_PER_FirstName (no m values are trained).
#     - PER_SSN (no m values are trained).
#     - new_address (no m values are trained).
#     - PER_DOB (no m values are trained).

# %%
linker.estimate_m_from_label_column("PER_SSN")
# Out:
# -------- Estimating m probabilities using from column PER_SSN --------
# m probability not trained for PER_SSN - Levenshtein <= 2 (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
# m probability not trained for PER_SSN - All other comparisons (comparison vector value: 0). This usually means the comparison level was never observed in the training data.
#
# Your model is not yet fully trained. Missing estimates for:
#     - PER_SSN (some m values are not trained).

# %%
linker.estimate_m_from_label_column("PER_CellularPhoneOrPager")
# Out:
#  Estimating m probabilities using from column PER_CellularPhoneOrPager
# m probability not trained for custom_PER_FirstName_PER_LastName - Exact match on reversed cols (comparison vector value: 5). This usually means the comparison level was never observed in the training data.
# m probability not trained for PER_SSN - Levenshtein <= 2 (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
#
# Your model is not yet fully trained. Missing estimates for:
#     - PER_SSN (some m values are not trained).

# %%
linker.estimate_m_from_label_column("PER_DOB")
# Out:
# -------- Estimating m probabilities using from column PER_DOB --------
# m probability not trained for PER_Email - Exact match PER_Email (comparison vector value: 2). This usually means the comparison level was never observed in the training data.
# m probability not trained for PER_Email - Jaro_winkler_similarity PER_Email >= 0.88 (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
# m probability not trained for PER_DOB - Damerau_levenshtein <= 1 (comparison vector value: 4). This usually means the comparison level was never observed in the training data.
# m probability not trained for PER_DOB - Within 1 month (comparison vector value: 3). This usually means the comparison level was never observed in the training data.
# m probability not trained for PER_DOB - Within 1 year (comparison vector value: 2). This usually means the comparison level was never observed in the training data.
# m probability not trained for PER_DOB - Within 10 years (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
# m probability not trained for PER_DOB - All other comparisons (comparison vector value: 0). This usually means the comparison level was never observed in the training data.
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
linker.match_weights_chart()
# Out:
# alt.VConcatChart(...)

# %%
linker.m_u_parameters_chart()
# Out:
# alt.HConcatChart(...)

# %%
linker.unlinkables_chart()
# Out:
# ---------------------------------------------------------------------------
# ParserException                           Traceback (most recent call last)
# File ~/miniforge3/envs/tomenv/lib/python3.11/site-packages/splink/linker.py:713, in Linker._log_and_run_sql_execution(self, final_sql, templated_name, physical_name)
#     712 try:
# --> 713     return self._run_sql_execution(final_sql, templated_name, physical_name)
#     714 except Exception as e:
#     715     # Parse our SQL through sqlglot to pretty print
#
# File ~/miniforge3/envs/tomenv/lib/python3.11/site-packages/splink/duckdb/linker.py:225, in DuckDBLinker._run_sql_execution(self, final_sql, templated_name, physical_name)
#     224 def _run_sql_execution(self, final_sql, templated_name, physical_name):
# --> 225     self._con.execute(final_sql)
#
# ParserException: Parser Error: syntax error at or near ")"
# LINE 26: ...EATE TABLE __splink__df_self_link_a4ddd82d3
#         AS
#         (WITH __splink__df_concat_with_tf as (select * from __splink__df_concat_with_tf_80ebfa5b2),
# __splink__df_blocked as (
#             select
#             "l"."id" AS "id_l", "r"."id" AS "id_r"
#             , '0' as match_key
#
#             from __splink__df_concat_with_tf as l
#             inner join __splink__df_concat_with_tf as r
#             on
#             (l."id" = r."id")
#              where 1=1
#
#             ),
# __splink__df_comparison_vectors as (
#     select "id_l","id_r"
#     from __splink__df_blocked
#     ),
# __splink__df_match_weight_parts as (
#     select "id_l","id_r"
#     from __splink__df_comparison_vectors
#     )
#     select
#     log2(cast(0.00010001000100010001 as float8) * ) as match_weight,
#                                                    ^
#
# The above exception was the direct cause of the following exception:
#
# SplinkException                           Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 linker.unlinkables_chart()
#
# File ~/miniforge3/envs/tomenv/lib/python3.11/site-packages/splink/linker.py:3087, in Linker.unlinkables_chart(self, x_col, source_dataset, as_dict)
#    3056 """Generate an interactive chart displaying the proportion of records that
#    3057 are "unlinkable" for a given splink score threshold and model parameters.
#    3058
#    (...)
#    3083     altair.Chart: An altair chart
#    3084 """
#    3086 # Link our initial df on itself and calculate the % of unlinkable entries
# -> 3087 records = unlinkables_data(self)
#    3088 return unlinkables_chart(records, x_col, source_dataset, as_dict)
#
# File ~/miniforge3/envs/tomenv/lib/python3.11/site-packages/splink/unlinkables.py:20, in unlinkables_data(linker)
#      10 def unlinkables_data(linker: Linker):
#      11     """Generate data displaying the proportion of records that are "unlinkable"
#      12     for a given splink score threshold and model parameters. These are records that,
#      13     even when compared with themselves, do not contain enough information to confirm
#    (...)
#      17         linker (Splink): A Splink data linker
#      18     """
# ---> 20     self_link = linker._self_link()
#      22     sql = f"""
#      23         select
#      24         round(match_weight, 2) as match_weight,
#      25         round(match_probability, 5) as match_probability
#      26         from {self_link.physical_name}
#      27     """
#      29     linker._enqueue_sql(sql, "__splink__df_round_self_link")
#
# File ~/miniforge3/envs/tomenv/lib/python3.11/site-packages/splink/linker.py:2064, in Linker._self_link(self)
#    2061     output_table_name = output_table_name.replace("predict", "self_link")
#    2062     self._enqueue_sql(sql["sql"], output_table_name)
# -> 2064 predictions = self._execute_sql_pipeline(
#    2065     input_dataframes=[nodes_with_tf], use_cache=False
#    2066 )
#    2068 self._settings_obj._blocking_rules_to_generate_predictions = (
#    2069     original_blocking_rules
#    2070 )
#    2071 self._settings_obj._link_type = original_link_type
#
# File ~/miniforge3/envs/tomenv/lib/python3.11/site-packages/splink/linker.py:651, in Linker._execute_sql_pipeline(self, input_dataframes, use_cache)
#     645     dataframe = self._sql_to_splink_dataframe_checking_cache(
#     646         sql_gen,
#     647         output_tablename_templated,
#     648         use_cache,
#     649     )
#     650 except Exception as e:
# --> 651     raise e
#     652 finally:
#     653     self._pipeline.reset()
#
# File ~/miniforge3/envs/tomenv/lib/python3.11/site-packages/splink/linker.py:645, in Linker._execute_sql_pipeline(self, input_dataframes, use_cache)
#     642 output_tablename_templated = self._pipeline.queue[-1].output_table_name
#     644 try:
# --> 645     dataframe = self._sql_to_splink_dataframe_checking_cache(
#     646         sql_gen,
#     647         output_tablename_templated,
#     648         use_cache,
#     649     )
#     650 except Exception as e:
#     651     raise e
#
# File ~/miniforge3/envs/tomenv/lib/python3.11/site-packages/splink/linker.py:911, in Linker._sql_to_splink_dataframe_checking_cache(self, sql, output_tablename_templated, use_cache)
#     908         print(df_pd)  # noqa: T201
#     910 else:
# --> 911     splink_dataframe = self._execute_sql_against_backend(
#     912         sql, output_tablename_templated, table_name_hash
#     913     )
#     914     self._intermediate_table_cache.executed_queries.append(splink_dataframe)
#     916 splink_dataframe.created_by_splink = True
#
# File ~/miniforge3/envs/tomenv/lib/python3.11/site-packages/splink/duckdb/linker.py:220, in DuckDBLinker._execute_sql_against_backend(self, sql, templated_name, physical_name)
#     213 self._delete_table_from_database(physical_name)
#     215 sql = f"""
#     216 CREATE TABLE {physical_name}
#     217 AS
#     218 ({sql})
#     219 """
# --> 220 self._log_and_run_sql_execution(sql, templated_name, physical_name)
#     222 return DuckDBDataFrame(templated_name, physical_name, self)
#
# File ~/miniforge3/envs/tomenv/lib/python3.11/site-packages/splink/linker.py:725, in Linker._log_and_run_sql_execution(self, final_sql, templated_name, physical_name)
#     722 except Exception:
#     723     pass
# --> 725 raise SplinkException(
#     726     f"Error executing the following sql for table "
#     727     f"`{templated_name}`({physical_name}):\n{final_sql}"
#     728     f"\n\nError was: {e}"
#     729 ) from e
#
# SplinkException: Error executing the following sql for table `__splink__df_self_link`(__splink__df_self_link_a4ddd82d3):
#
#         CREATE TABLE __splink__df_self_link_a4ddd82d3
#         AS
#         (WITH __splink__df_concat_with_tf as (select * from __splink__df_concat_with_tf_80ebfa5b2),
# __splink__df_blocked as (
#             select
#             "l"."id" AS "id_l", "r"."id" AS "id_r"
#             , '0' as match_key
#
#             from __splink__df_concat_with_tf as l
#             inner join __splink__df_concat_with_tf as r
#             on
#             (l."id" = r."id")
#              where 1=1
#
#             ),
# __splink__df_comparison_vectors as (
#     select "id_l","id_r"
#     from __splink__df_blocked
#     ),
# __splink__df_match_weight_parts as (
#     select "id_l","id_r"
#     from __splink__df_comparison_vectors
#     )
#     select
#     log2(cast(0.00010001000100010001 as float8) * ) as match_weight,
#     CASE WHEN  THEN 1.0 ELSE (cast(0.00010001000100010001 as float8) * )/(1+(cast(0.00010001000100010001 as float8) * )) END as match_probability,
#     "id_l","id_r"
#     from __splink__df_match_weight_parts
#
#     order by 1
#     )
#
#
# Error was: Parser Error: syntax error at or near ")"
# LINE 26: ...EATE TABLE __splink__df_self_link_a4ddd82d3
#         AS
#         (WITH __splink__df_concat_with_tf as (select * from __splink__df_concat_with_tf_80ebfa5b2),
# __splink__df_blocked as (
#             select
#             "l"."id" AS "id_l", "r"."id" AS "id_r"
#             , '0' as match_key
#
#             from __splink__df_concat_with_tf as l
#             inner join __splink__df_concat_with_tf as r
#             on
#             (l."id" = r."id")
#              where 1=1
#
#             ),
# __splink__df_comparison_vectors as (
#     select "id_l","id_r"
#     from __splink__df_blocked
#     ),
# __splink__df_match_weight_parts as (
#     select "id_l","id_r"
#     from __splink__df_comparison_vectors
#     )
#     select
#     log2(cast(0.00010001000100010001 as float8) * ) as match_weight,
#                                                    ^

# %%
cleaned_df9_subset.columns
# Out:
# Index(['PER_LastName', 'PER_FirstName', 'PER_MiddleName', 'PER_SSN', 'PER_DOB',
#        'PER_HomePhone', 'PER_CellularPhoneOrPager', 'PER_Email', 'city_valid',
#        'state_valid', 'zip_valid', 'apt_valid', 'new_address',
#        'new_address_unit', 'id', 'firstname_dm', 'lastname_dm',
#        'middlename_dm', 'full_name'],
#       dtype='object')

# %%
from splink.duckdb.blocking_rule_library import block_on

settings = {
     "unique_id_column_name": "id",
    "link_type": "dedupe_only",
    "comparisons": [
        ctl.name_comparison("firstname_dm"),
        ctl.name_comparison("lastname_dm"),
        ctl.date_comparison("PER_DOB"),
        cl.exact_match("city_valid", term_frequency_adjustments=True),
        ctl.email_comparison("PER_Email", include_username_fuzzy_level=False),
    ],
    "blocking_rules_to_generate_predictions": [
        block_on("PER_FirstName"),
        block_on("PER_LastName"),
    ],
    "retain_matching_columns": True,
    "retain_intermediate_calculation_columns": True,
}

linker = DuckDBLinker(cleaned_df9_subset, settings)

# %%
linker.estimate_u_using_random_sampling(max_pairs=1e8)
# Out:
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - firstname_dm (no m values are trained).
#     - lastname_dm (no m values are trained).
#     - PER_DOB (no m values are trained).
#     - city_valid (no m values are trained).
#     - PER_Email (no m values are trained).

# %%
linker.estimate_m_from_label_column("PER_SSN")
# Out:
# -------- Estimating m probabilities using from column PER_SSN --------
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
linker.estimate_m_from_label_column("middlename_dm")
# Out:
# ----- Estimating m probabilities using from column middlename_dm -----
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
linker.match_weights_chart()
# Out:
# alt.VConcatChart(...)

# %%
linker.m_u_parameters_chart()
# Out:
# alt.HConcatChart(...)

# %%
linker.estimate_m_from_label_column("middlename_dm")
# Out:
# ----- Estimating m probabilities using from column middlename_dm -----
#
# Your model is not yet fully trained. Missing estimates for:
#     - PER_Email (some u values are not trained).

# %%
cleaned_df9_subset.columns
# Out:
# Index(['PER_LastName', 'PER_FirstName', 'PER_MiddleName', 'PER_SSN', 'PER_DOB',
#        'PER_HomePhone', 'PER_CellularPhoneOrPager', 'PER_Email', 'city_valid',
#        'state_valid', 'zip_valid', 'apt_valid', 'new_address',
#        'new_address_unit', 'id', 'firstname_dm', 'lastname_dm',
#        'middlename_dm', 'full_name'],
#       dtype='object')

# %%
 # Complete settings dictionary
settings = {
      "unique_id_column_name": "id",
    "link_type": "dedupe_only",
    "comparisons": [
        cl.exact_match("firstname_dm"),
        cl.exact_match("lastname_dm"),        
        cl.levenshtein_at_thresholds("PER_DOB", 1),
        cl.exact_match("city_valid", term_frequency_adjustments=True),
        #ctl.email_comparison("PER_Email", include_username_fuzzy_level=False),
        cl.levenshtein_at_thresholds("PER_SSN", [2]),
        cl.exact_match("new_address", term_frequency_adjustments=True),
    ],        
    "blocking_rules_to_generate_predictions": [
        "l.PER_FirstName = r.PER_FirstName",
        "l.PER_LastName = r.PER_LastName",
    ],
    "retain_matching_columns": True,
    "retain_intermediate_calculation_columns": True,
}

linker = DuckDBLinker(cleaned_df9_subset, settings)

# %%
deterministic_rules = [
    "l.PER_FirstName = r.PER_FirstName and levenshtein(r.PER_DOB, l.PER_DOB) <= 1",
    "l.PER_LastName = r.PER_LastName and levenshtein(r.PER_DOB, l.PER_DOB) <= 1",
    "l.PER_FirstName = r.PER_FirstName and levenshtein(r.PER_LastName, l.PER_LastName) <= 2",
]

linker.estimate_probability_two_random_records_match(deterministic_rules, recall=0.7)
# Out:
# Probability two random records match is estimated to be  3.83e-05.
# This means that amongst all possible pairwise record comparisons, one in 26,097.32 are expected to match.  With 49,995,000 total possible comparisons, we expect a total of around 1,915.71 matching pairs

# %%
 linker.estimate_u_using_random_sampling(max_pairs=1e6)
# Out:
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - firstname_dm (no m values are trained).
#     - lastname_dm (no m values are trained).
#     - PER_DOB (no m values are trained).
#     - city_valid (no m values are trained).
#     - PER_SSN (no m values are trained).
#     - new_address (no m values are trained).

# %%
from numpy import fix
training_blocking_rule = block_on("PER_DOB")
training_session_dob = linker.estimate_parameters_using_expectation_maximisation(training_blocking_rule)
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l."PER_DOB" = r."PER_DOB"
#
# Parameter estimates will be made for the following comparison(s):
#     - firstname_dm
#     - lastname_dm
#     - city_valid
#     - PER_SSN
#     - new_address
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - PER_DOB
#
# Iteration 1: Largest change in params was -0.294 in the m_probability of PER_SSN, level `Exact match`
# Iteration 2: Largest change in params was 0.323 in the m_probability of new_address, level `All other comparisons`
# Iteration 3: Largest change in params was 0.0329 in the m_probability of firstname_dm, level `All other comparisons`
# Iteration 4: Largest change in params was 0.00724 in the m_probability of firstname_dm, level `All other comparisons`
# Iteration 5: Largest change in params was -0.00131 in the m_probability of firstname_dm, level `Exact match`
# Iteration 6: Largest change in params was -0.000246 in the m_probability of lastname_dm, level `Exact match`
# Iteration 7: Largest change in params was 5.01e-05 in the m_probability of lastname_dm, level `All other comparisons`
#
# EM converged after 7 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - PER_DOB (no m values are trained).

# %%
training_blocking_rule = block_on(["firstname_dm", "lastname_dm"])
training_session_fname_sname = linker.estimate_parameters_using_expectation_maximisation(training_blocking_rule)
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."firstname_dm" = r."firstname_dm") AND (l."lastname_dm" = r."lastname_dm")
#
# Parameter estimates will be made for the following comparison(s):
#     - PER_DOB
#     - city_valid
#     - PER_SSN
#     - new_address
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - firstname_dm
#     - lastname_dm
#
# Iteration 1: Largest change in params was -0.202 in probability_two_random_records_match
# Iteration 2: Largest change in params was 0.0118 in the m_probability of PER_DOB, level `Exact match`
# Iteration 3: Largest change in params was -0.00669 in the m_probability of PER_DOB, level `All other comparisons`
# Iteration 4: Largest change in params was -0.00355 in the m_probability of PER_DOB, level `All other comparisons`
# Iteration 5: Largest change in params was -0.00187 in the m_probability of PER_DOB, level `All other comparisons`
# Iteration 6: Largest change in params was -0.000979 in the m_probability of PER_DOB, level `All other comparisons`
# Iteration 7: Largest change in params was -0.000514 in the m_probability of PER_DOB, level `All other comparisons`
# Iteration 8: Largest change in params was -0.00027 in the m_probability of PER_DOB, level `All other comparisons`
# Iteration 9: Largest change in params was -0.000142 in the m_probability of PER_DOB, level `All other comparisons`
# Iteration 10: Largest change in params was -7.46e-05 in the m_probability of PER_DOB, level `All other comparisons`
#
# EM converged after 10 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
# We will first fix `name` and `surname` to match in order to estimate the other columns' m probabilities.
# Then we will fix the `dob`.
training_blocking_rule = "l.PER_FirstName = r.PER_FirstName and l.PER_LastName = r.PER_LastName"
training_session_fname_sname = linker.estimate_parameters_using_expectation_maximisation(training_blocking_rule)
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.PER_FirstName = r.PER_FirstName and l.PER_LastName = r.PER_LastName
#
# Parameter estimates will be made for the following comparison(s):
#     - firstname_dm
#     - lastname_dm
#     - PER_DOB
#     - city_valid
#     - PER_SSN
#     - new_address
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#
# WARNING:
# Level All other comparisons on comparison firstname_dm not observed in dataset, unable to train m value
#
# WARNING:
# Level All other comparisons on comparison lastname_dm not observed in dataset, unable to train m value
#
# Iteration 1: Largest change in params was 0.845 in probability_two_random_records_match
# Iteration 2: Largest change in params was 0.155 in probability_two_random_records_match
# Iteration 3: Largest change in params was 6.19e-05 in probability_two_random_records_match
#
# EM converged after 3 iterations
# m probability not trained for firstname_dm - All other comparisons (comparison vector value: 0). This usually means the comparison level was never observed in the training data.
# m probability not trained for lastname_dm - All other comparisons (comparison vector value: 0). This usually means the comparison level was never observed in the training data.
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
 # The final estimated match weights
linker.match_weights_chart()
# Out:
# alt.VConcatChart(...)

# %%
linker.m_u_parameters_chart()
# Out:
# alt.HConcatChart(...)

# %%
linker.unlinkables_chart()
# Out:
# alt.LayerChart(...)

# %%
df_predictions = linker.predict(threshold_match_probability=0.2)

# %%
clusters = linker.cluster_pairwise_predictions_at_threshold(df_predictions, threshold_match_probability=0.5)
df_predictions.as_pandas_dataframe()
df_predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 clusters = linker.cluster_pairwise_predictions_at_threshold(df_predictions, threshold_match_probability=0.5)
#       2 df_predictions.as_pandas_dataframe()
#       3 df_predictions
#
# NameError: name 'linker' is not defined
